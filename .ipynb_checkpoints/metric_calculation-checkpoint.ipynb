# %%
import re
import pandas as pd
import numpy as np

# %%
filtered_df = pd.read_csv("filtered_news_cat.csv")

# %%
filtered_df.head()
# Out:
#   category                                           headline  \
# 0    CRIME  25 Years To Life For Man Who Killed Family In ...
# 1    CRIME  Ahmad Khan Rahami's Dad: I Reported My Son To ...
# 2    CRIME  Cops Catch Burglary Suspects Passed Out In Car...
# 3    CRIME                   Unease Grows Between Mayor, NYPD
# 4    CRIME  Man Mailed Dead Skunks, Raccoon To Rival For J...
#
#            authors                                               link  \
# 0              NaN  https://www.huffingtonpost.com/entry/nyc-man-s...
# 1    Ryan Grenoble  https://www.huffingtonpost.com/entry/mohammad-...
# 2              NaN  https://www.huffingtonpost.com/entry/burglars-...
# 3  Simon McCormack  https://www.huffingtonpost.com/entry/nypd-nyc-...
# 4              NaN  https://www.huffingtonpost.com/entry/travis-ta...
#
#                                    short_description        date
# 0                                                NaN  2015-04-14
# ...

# %% [markdown]
# # Query 1
# ### headline : domestic violence

# %%
re_output = filtered_df[filtered_df['headline'].str.contains('domestic violence',regex=True, na=False, case = False)]

# %%
re_output
# Out:
#        category                                           headline  \
# 106       CRIME  Texas Massacre Suspect Had Previous Domestic V...
# 540  WORLD NEWS      Reducing Domestic Violence Helps All Of Haiti
# 743    POLITICS  Domestic Violence Still Not Grounds For Divorc...
# 885      SPORTS  Rutgers Football Star Pleads Not Guilty To Dom...
# 892      SPORTS  Male-Run Domestic Violence Group Apologizes Fo...
#
#                                                authors  \
# 106                                      Andy Campbell
# 540  Bjorn Lomborg, ContributorBjorn Lomborg is dir...
# 743                                    Melissa Jeltsen
# 885                                                NaN
# 892                                   Maxwell Strachan
#
#                                                   link  \
# 106  https://www.huffingtonpost.com/entry/ron-lee-h...
# 540  https://www.huffingtonpost.com/entry/reducing-...
# 743  https://www.huffingtonpost.com/entry/domestic-...
# ...

# %% [markdown]
# # Query 2
# ### headline : movie podcast

# %%
re_output_2 = filtered_df[filtered_df['headline'].str.contains('movie podcast',regex=True, na=False, case = False)]

# %%
re_output_2
# Out:
#           category                                           headline  \
# 232  ENTERTAINMENT  Mighty Movie Podcast: Joe Avella on Master of ...
# 258  ENTERTAINMENT  Mighty Movie Podcast: Writer Katie Dippold on ...
# 355  ENTERTAINMENT          Mighty Movie Podcast: Pablo Larrain on No
#
#                                         authors  \
# 232  Dan Persons, Contributor\nProducer - CFQtv
# 258  Dan Persons, Contributor\nProducer - CFQtv
# 355  Dan Persons, Contributor\nProducer - CFQtv
#
#                                                   link  \
# 232  https://www.huffingtonpost.com/entry/cinefanta...
# 258  https://www.huffingtonpost.com/entry/mighty-mo...
# 355  https://www.huffingtonpost.com/entry/mighty-mo...
#
#                                      short_description        date
# 232  If you ever wondered whether the people who co...  2013-03-03
# 258  The Heat isn't shy about acknowledging its deb...  2013-06-30
# ...

# %% [markdown]
# # Query 3
# ### short_description : mass shooting

# %%
re_output_3 = filtered_df[filtered_df['short_description'].str.contains('mass shooting',regex=True, na=False, case = False)]

# %%
re_output_3
# Out:
#     category                                           headline      authors  \
# 126    CRIME  San Bernardino Police Officer: 'I'll Take A Bu...  Marina Fang
# 199    CRIME  Newtown Shooter May Have Had Interest In Pedop...   Willa Frej
#
#                                                   link  \
# 126  https://www.huffingtonpost.com/entry/san-berna...
# 199  https://www.huffingtonpost.com/entry/adam-lanz...
#
#                                      short_description        date
# 126  The officer was evacuating people from the Inl...  2015-12-03
# 199  Adam Lanza thought children were being brainwa...  2017-10-25

# %% [markdown]
# # Query 4
# ### short_description:foreign policy

# %%
re_output_4 = filtered_df[filtered_df['short_description'].str.contains('foreign policy',regex=True, na=False, case = False)]

# %%
re_output_4
# Out:
#      category                                           headline  \
# 693  POLITICS                                     Sunday Roundup
# 695  POLITICS  With North Korea, A Military Option Means Nucl...
#
#                                                authors  \
# 693                    Arianna Huffington, Contributor
# 695  Lillyanne Daigle, ContributorNetwork Campaigne...
#
#                                                   link  \
# 693  https://www.huffingtonpost.com/entry/sunday-ro...
# 695  https://www.huffingtonpost.com/entry/with-nort...
#
#                                      short_description        date
# 693  This week, Hillary Clinton took on the war aga...  2015-06-07
# 695  This tense clash between two nuclear-armed and...  2017-04-15

# %% [markdown]
# # Query 5
# ### short_description:fraud

# %%
re_output_5 = filtered_df[filtered_df['short_description'].str.contains('fraud',regex=True, na=False, case = False)]

# %%
re_output_5
# Out:
#      category                                           headline  \
# 7       CRIME  Brother Of San Bernardino Shooter Among 3 Arre...
# 38      CRIME  Accused Fake 'Teen Doctor' Malachi Love-Robins...
# 693  POLITICS                                     Sunday Roundup
# 705  POLITICS  North Carolina State Board Of Election Investi...
#
#                              authors  \
# 7                                NaN
# 38               Dominique Mosbergen
# 693  Arianna Huffington, Contributor
# 705                     Julia Craven
#
#                                                   link  \
# 7    https://www.huffingtonpost.com/entry/san-berna...
# 38   https://www.huffingtonpost.com/entry/malachi-l...
# 693  https://www.huffingtonpost.com/entry/sunday-ro...
# 705  https://www.huffingtonpost.com/entry/north-car...
#
#                                      short_description        date
# 7    The three were arrested on charges of federal ...  2016-04-28
# ...
